# %% [markdown]
# # Lecture 03 September 2020
#
# ## Example of plotting

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
data = np.random.randn(100).cumsum()
plt.plot(data)
